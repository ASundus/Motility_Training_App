# %% [markdown]
# <a href="https://colab.research.google.com/github/ASundus/Motility_Training_App/blob/master/Cell_Mechanics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/url-it/tr_mechanics.git
import sys, os
os.chdir("tr_mechanics")
sys.path.insert(0, os.path.abspath('bin'))
import tr_mechanics
tr_mechanics.gui
# Out:
# Cloning into 'tr_mechanics'...
# remote: Enumerating objects: 215, done.
# remote: Counting objects: 100% (215/215), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 215 (delta 110), reused 180 (delta 75), pack-reused 0 (from 0)
# Receiving objects: 100% (215/215), 866.90 KiB | 3.13 MiB/s, done.
# Resolving deltas: 100% (110/110), done.
# Executable permissions granted for: /content/tr_mechanics/bin/myproj
# VBox(children=(HBox(children=(Label(value='tr_mechanics'),)), Tab(children=(Output(layout=Layout(height='auto'…
