# %% [markdown]
# <a href="https://colab.research.google.com/github/ASundus/Motility_Training_App/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/url-it/tr_mechanics.git
import sys, os
os.chdir("tr_mechanics")
sys.path.insert(0, os.path.abspath('bin'))
import tr_mechanics
tr_mechanics.gui
